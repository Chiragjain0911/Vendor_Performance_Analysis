# %%
import pandas as pd
import sqlite3


db_path = "/content/drive/MyDrive/inventory.db"


conn = sqlite3.connect(db_path)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
Tables = pd.read_sql_query("SELECT name FROM sqlite_master WHERE type='table';", conn)
print(Tables)
# Out:
#                    name
# 0       begin_inventory
# 1         end_inventory
# 2       purchase_prices
# 3             purchases
# 4                 sales
# 5        vendor_invoice
# 6  vendor_sales_summary
# 7   vendor_sale_summary

# %%
for table in Tables['name']:
  print("-"*50,f'{table}',"-"*50)
  print('Count of record:',pd.read_sql_query(f'select count(*) as count from {table}',conn)['count'].values[0])
  display(pd.read_sql_query(f'select * from {table} limit 5',conn))
# Out:
# -------------------------------------------------- begin_inventory --------------------------------------------------
# Count of record: 206529
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_60      1  HARDERSFIELD     60       Canadian Club 1858 VAP
# 2  1_HARDERSFIELD_62      1  HARDERSFIELD     62     Herradura Silver Tequila
# 3  1_HARDERSFIELD_63      1  HARDERSFIELD     63   Herradura Reposado Tequila
# 4  1_HARDERSFIELD_72      1  HARDERSFIELD     72         No. 3 London Dry Gin
#
#     Size  onHand  Price   startDate
# 0  750mL       8  12.99  2024-01-01
# 1  750mL       7  10.99  2024-01-01
# 2  750mL       6  36.99  2024-01-01
# 3  750mL       3  38.99  2024-01-01
# 4  750mL       6  34.99  2024-01-01
# -------------------------------------------------- end_inventory --------------------------------------------------
# ...

# %% [markdown]
# lets understand how data are connected by analyzing anyone vendor purchase adn selling

# %%
purchases = pd.read_sql_query('select * from purchases where VendorNumber = 4466',conn)
purchases
# Out:
#              InventoryId  Store  Brand                   Description   Size  \
# 0       30_CULCHETH_5255     30   5255  TGI Fridays Ultimte Mudslide  1.75L
# 1      34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
# 2    1_HARDERSFIELD_5255      1   5255  TGI Fridays Ultimte Mudslide  1.75L
# 3      38_GOULCREST_5215     38   5215  TGI Fridays Long Island Iced  1.75L
# 4    59_CLAETHORPES_5215     59   5215  TGI Fridays Long Island Iced  1.75L
# ..                   ...    ...    ...                           ...    ...
# 146      33_HORNSEY_5255     33   5255  TGI Fridays Ultimte Mudslide  1.75L
# 147    38_GOULCREST_5255     38   5255  TGI Fridays Ultimte Mudslide  1.75L
# 148    50_MOUNTMEND_5215     50   5215  TGI Fridays Long Island Iced  1.75L
# 149    73_DONCASTER_5215     73   5215  TGI Fridays Long Island Iced  1.75L
# 150    76_DONCASTER_5255     76   5255  TGI Fridays Ultimte Mudslide  1.75L
#
# ...

# %%
purchase_prices= pd.read_sql_query('select * from purchase_prices where VendorNumber = 4466',conn)
purchase_prices
# Out:
#    Brand                   Description  Price    Size Volume  Classification  \
# 0   5215  TGI Fridays Long Island Iced  12.99  1750mL   1750               1
# 1   5255  TGI Fridays Ultimte Mudslide  12.99  1750mL   1750               1
# 2   3140      TGI Fridays Orange Dream  14.99  1750mL   1750               1
#
#    PurchasePrice  VendorNumber                   VendorName
# 0           9.41          4466  AMERICAN VINTAGE BEVERAGE
# 1           9.35          4466  AMERICAN VINTAGE BEVERAGE
# 2          11.19          4466  AMERICAN VINTAGE BEVERAGE

# %%
invoices = pd.read_sql_query('select * from vendor_invoice where VendorNumber = 4466',conn)
invoices
# Out:
#     VendorNumber                   VendorName InvoiceDate  PONumber  \
# 0           4466  AMERICAN VINTAGE BEVERAGE    2024-01-07      8137
# 1           4466  AMERICAN VINTAGE BEVERAGE    2024-01-19      8207
# 2           4466  AMERICAN VINTAGE BEVERAGE    2024-01-18      8307
# 3           4466  AMERICAN VINTAGE BEVERAGE    2024-01-27      8469
# 4           4466  AMERICAN VINTAGE BEVERAGE    2024-02-04      8532
# 5           4466  AMERICAN VINTAGE BEVERAGE    2024-02-09      8604
# 6           4466  AMERICAN VINTAGE BEVERAGE    2024-02-17      8793
# 7           4466  AMERICAN VINTAGE BEVERAGE    2024-03-01      8892
# 8           4466  AMERICAN VINTAGE BEVERAGE    2024-03-07      8995
# 9           4466  AMERICAN VINTAGE BEVERAGE    2024-03-12      9033
# 10          4466  AMERICAN VINTAGE BEVERAGE    2024-03-16      9180
# 11          4466  AMERICAN VINTAGE BEVERAGE    2024-03-23      9244
# 12          4466  AMERICAN VINTAGE BEVERAGE    2024-03-31      9371
# ...

# %%
sales = pd.read_sql_query('select * from sales where VendorNo = 4466',conn)
sales
# Out:
#             InventoryId  Store  Brand                   Description   Size  \
# 0   1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 1   1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 2   1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 3   1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 4   1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# ..                  ...    ...    ...                           ...    ...
# 84    27_MOUNTMEND_5255     27   5255  TGI Fridays Ultimte Mudslide  1.75L
# 85    27_MOUNTMEND_5255     27   5255  TGI Fridays Ultimte Mudslide  1.75L
# 86    27_MOUNTMEND_5255     27   5255  TGI Fridays Ultimte Mudslide  1.75L
# 87    27_MOUNTMEND_5255     27   5255  TGI Fridays Ultimte Mudslide  1.75L
# 88    27_MOUNTMEND_5255     27   5255  TGI Fridays Ultimte Mudslide  1.75L
#
#     SalesQuantity  SalesDollars  SalesPrice   SalesDate  Volume  \
# ...

# %%
purchases.groupby(['Brand','PurchasePrice'])[['Quantity','Dollars']].sum()
# Out:
#                      Quantity  Dollars
# Brand PurchasePrice
# 5215  9.41              552.0  5194.32
# 5255  9.35              526.0  4918.10

# %%
purchase_prices
# Out:
#    Brand                   Description  Price    Size Volume  Classification  \
# 0   5215  TGI Fridays Long Island Iced  12.99  1750mL   1750               1
# 1   5255  TGI Fridays Ultimte Mudslide  12.99  1750mL   1750               1
# 2   3140      TGI Fridays Orange Dream  14.99  1750mL   1750               1
#
#    PurchasePrice  VendorNumber                   VendorName
# 0           9.41          4466  AMERICAN VINTAGE BEVERAGE
# 1           9.35          4466  AMERICAN VINTAGE BEVERAGE
# 2          11.19          4466  AMERICAN VINTAGE BEVERAGE

# %% [markdown]
# purchases = purchases_price + vendor_invoice

# %%
sales
# Out:
#             InventoryId  Store  Brand                   Description   Size  \
# 0   1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 1   1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 2   1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 3   1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 4   1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# ..                  ...    ...    ...                           ...    ...
# 84    27_MOUNTMEND_5255     27   5255  TGI Fridays Ultimte Mudslide  1.75L
# 85    27_MOUNTMEND_5255     27   5255  TGI Fridays Ultimte Mudslide  1.75L
# 86    27_MOUNTMEND_5255     27   5255  TGI Fridays Ultimte Mudslide  1.75L
# 87    27_MOUNTMEND_5255     27   5255  TGI Fridays Ultimte Mudslide  1.75L
# 88    27_MOUNTMEND_5255     27   5255  TGI Fridays Ultimte Mudslide  1.75L
#
#     SalesQuantity  SalesDollars  SalesPrice   SalesDate  Volume  \
# ...

# %%
sales.groupby(['Brand'])[['SalesQuantity','SalesDollars','SalesPrice']].sum()
# Out:
#        SalesQuantity  SalesDollars  SalesPrice
# Brand
# 5215              46        597.54      480.63
# 5255              66        857.34      675.48

# %%
purchases.groupby(['Brand','PurchasePrice'])[['Quantity','Dollars']].sum()
# Out:
#                      Quantity  Dollars
# Brand PurchasePrice
# 5215  9.41              552.0  5194.32
# 5255  9.35              526.0  4918.10

# %% [markdown]
# ***From the above observation we gather some points on tables are:***
#
#
# ---
#
#
#
# *   The purchase table contains actual purchase data, including the date of purchase, products(brands) purchased by vendors, the amount paid in $, and the quantity purchased.
# *   The purchase price column is derived from the purchase_table, which provides product-wise actual and purchase prices. The combination of vendor and brands unique in this table.
#
# *   The vendor_invoice table aggregates data from purchase table, summarizing quantity and dollar amounts, along with additional column for frieght. This table maintains uniqueness based on vendor and PO number
# *   The sales table captures actual sales transactions, detailing the brands purchased by vendors, the quantity sold,the selling price and the revenue earned.

# %% [markdown]
# ***We obsereved data is distributed in different tables, for anlysis we need to crete a summary tbale containing:***
#
# ---
#
#
#
# *   purchases transactions made by vendors
# *   sales transaction data
#
# *   freight cost for each vendor
# *   actual product prices from vendors

# %%
frieght_summary = pd.read_sql_query('''select VendorNumber, SUM(Freight) as FreighhtCost
From vendor_invoice
Group by VendorNumber''',conn)
frieght_summary
# Out:
#      VendorNumber  FreighhtCost
# 0               2         27.08
# 1              54          0.48
# 2              60        367.52
# 3             105         62.39
# 4             200          6.19
# ..            ...           ...
# 121         98450        856.02
# 122         99166        130.09
# 123        172662        178.34
# 124        173357        202.50
# 125        201359          0.09
#
# [126 rows x 2 columns]

# %%
purchases.columns
# Out:
# Index(['InventoryId', 'Store', 'Brand', 'Description', 'Size', 'VendorNumber',
#        'VendorName', 'PONumber', 'PODate', 'ReceivingDate', 'InvoiceDate',
#        'PayDate', 'PurchasePrice', 'Quantity', 'Dollars', 'Classification'],
#       dtype='object')

# %%
purchase_prices.columns
# Out:
# Index(['Brand', 'Description', 'Price', 'Size', 'Volume', 'Classification',
#        'PurchasePrice', 'VendorNumber', 'VendorName'],
#       dtype='object')

# %%
pd.read_sql_query('''Select
p.VendorNumber,
p.VendorName,
p.Brand,
p.Description,
p.Purchaseprice,
pp.Volume,
pp.Price as ActualPrice,
SUM(p.Quantity) as TotalPurchaseQuantity,
SUM(p.Dollars) as TotalPurchaseDollars
FROM purchases p
JOIN purchase_prices pp
ON p.Brand = pp.Brand
Where p.PurchasePrice > 0
Group by p.VendorNumber, p.VendorName, p.Brand
Order by TotalPurchaseDollars''',conn)
# Out:
#       VendorNumber                   VendorName  Brand  \
# 0             7245  PROXIMO SPIRITS INC.          3065
# 1             3960  DIAGEO NORTH AMERICA INC      8495
# 2             6213  MHW LTD                       4703
# 3             9165  ULTRA BEVERAGE COMPANY LLP    9191
# 4             9815  WINE GROUP INC               22407
# ...            ...                          ...    ...
# 6489           480  BACARDI USA INC               3858
# 6490          4425        MARTIGNETTI COMPANIES   3405
# 6491          3960  DIAGEO NORTH AMERICA INC      3545
# 6492          1128  BROWN-FORMAN CORP             1233
# 6493          3960  DIAGEO NORTH AMERICA INC      4261
#
#                       Description  PurchasePrice Volume  ActualPrice  \
# 0        Three Olives Grape Vodka           0.71     50         0.99
# 1     Capt Morgan White Pineapple           0.71     50         0.99
# 2      Blue Chair Bay Coconut Rum           0.77     50         0.99
# ...

# %%
sales.columns
# Out:
# Index(['InventoryId', 'Store', 'Brand', 'Description', 'Size', 'SalesQuantity',
#        'SalesDollars', 'SalesPrice', 'SalesDate', 'Volume', 'Classification',
#        'ExciseTax', 'VendorNo', 'VendorName'],
#       dtype='object')

# %%
pd.read_sql_query('''Select
VendorNo,
Brand,
SUM(SalesDollars) as TotalSalesDollars,
SUM(SalesQuantity) as TotalSalesQuantity,
SUM(SalesPrice) as TotalSalesPrice,
SUM(ExciseTax) as TotalExciseTax
From sales
Group by VendorNo, Brand
Order by TotalSalesDollars''',conn)
# Out:
#       VendorNo  Brand  TotalSalesDollars  TotalSalesQuantity  TotalSalesPrice  \
# 0         8004   5287               0.49                   1             0.49
# 1         3960   8729               0.99                   1             0.99
# 2         7245   3065               0.99                   1             0.99
# 3         9625   8872               0.99                   1             0.99
# 4         3960   4173               1.98                   2             0.99
# ...        ...    ...                ...                 ...              ...
# 4952      4425   3405           46994.33                1567         12445.85
# 4953     17035   8068           58645.32                2268         12059.34
# 4954      3960   3545           65514.25                2175         12583.83
# 4955      1128   1233           68812.88                1912         16447.43
# 4956      3960   4261           91940.19                4181         10929.03
#
#       TotalExciseTax
# ...

# %%
import time
start = time.time()
vendor_sales_summary = pd.read_sql_query('''WITH FrieghtSummary AS(select VendorNumber, SUM(Freight) as FreighhtCost
From vendor_invoice
Group by VendorNumber),
PurchaseSummary AS(Select
p.VendorNumber,
p.VendorName,
p.Brand,
p.Description,
p.Purchaseprice,
pp.Volume,
pp.Price as ActualPrice,
SUM(p.Quantity) as TotalPurchaseQuantity,
SUM(p.Dollars) as TotalPurchaseDollars
FROM purchases p
JOIN purchase_prices pp
ON p.Brand = pp.Brand
Where p.PurchasePrice > 0
Group by p.VendorNumber, p.VendorName, p.Brand, p.Description, p.PurchasePrice,
pp.Volume, pp.Price
),
SalesSummary as(Select
VendorNo,
Brand,
SUM(SalesDollars) as TotalSalesDollars,
SUM(SalesQuantity) as TotalSalesQuantity,
SUM(SalesPrice) as TotalSalesPrice,
SUM(ExciseTax) as TotalExciseTax
From sales
Group by VendorNo, Brand)
SELECT
ps.VendorNumber,
ps.VendorName,
ps.Brand,
ps.Purchaseprice,
ps.Volume,
ps.ActualPrice,
ps.TotalPurchaseQuantity,
ps.TotalPurchaseDollars,
ss.TotalSalesQuantity,
ss.TotalSalesDollars,
ss.TotalSalesPrice,
ss.TotalExciseTax,
fs.FreighhtCost
FROM PurchaseSummary ps
LEFT JOIN SalesSummary ss
ON ps.VendorNumber = ss.VendorNo
AND ps.Brand = ss.Brand
JOIN FrieghtSummary fs
ON ps.VendorNumber = fs.VendorNumber
order by ps.TotalPurchaseDollars desc
''',conn)
end = time.time()
print(end-start)
vendor_sales_summary
# Out:
# 0.8799591064453125
#       VendorNumber                   VendorName  Brand  Purchaseprice Volume  \
# 0             3960  DIAGEO NORTH AMERICA INC      4261          16.17   1750
# 1             1128  BROWN-FORMAN CORP             1233          26.27   1750
# 2             3960  DIAGEO NORTH AMERICA INC      3545          21.89   1750
# 3             4425        MARTIGNETTI COMPANIES   3405          23.19   1750
# 4              480  BACARDI USA INC               3858          17.77    750
# ...            ...                          ...    ...            ...    ...
# 6489          9815  WINE GROUP INC               22407           2.25    750
# 6490          9165  ULTRA BEVERAGE COMPANY LLP    9191           0.73     50
# 6491          6213  MHW LTD                       4703           0.77     50
# 6492          3960  DIAGEO NORTH AMERICA INC      8495           0.71     50
# 6493          7245  PROXIMO SPIRITS INC.          3065           0.71     50
#
# ...

# %% [markdown]
# ***This Query generates a vendor-wise sales and purchase summary, which is valuable for:***
# # Performance OPtimization:

# %% [markdown]
# *   The query involves heavy joins and aggregations on large datasets like sales and purchases.
# *   Storing the pre-aggregated results avoids repeated expensive computations.
#
# *   Helps in analyzing sales, purchases and pricing for different vendors and brands.
# *   Future benefits of Storing this data for faster Dashboarding & Reporting.
#
# *   Instead of running expensive queries each tiem, dashboards can fetch data quickly from vendor_sales_summary.

# %% [markdown]
# # Check Data validation & cleaning of data

# %%
vendor_sales_summary.dtypes
# Out:
# VendorNumber               int64
# VendorName                object
# Brand                      int64
# Purchaseprice            float64
# Volume                    object
# ActualPrice              float64
# TotalPurchaseQuantity    float64
# TotalPurchaseDollars     float64
# TotalSalesQuantity       float64
# TotalSalesDollars        float64
# TotalSalesPrice          float64
# TotalExciseTax           float64
# FreighhtCost             float64
# dtype: object

# %%
vendor_sales_summary.isnull().sum()
# Out:
# VendorNumber                0
# VendorName                  0
# Brand                       0
# Purchaseprice               0
# Volume                      0
# ActualPrice                 0
# TotalPurchaseQuantity       0
# TotalPurchaseDollars        0
# TotalSalesQuantity       1844
# TotalSalesDollars        1844
# TotalSalesPrice          1844
# TotalExciseTax           1844
# FreighhtCost                0
# dtype: int64

# %%
vendor_sales_summary['VendorName'].unique()
# Out:
# array(['DIAGEO NORTH AMERICA INC   ', 'BROWN-FORMAN CORP          ',
#        'MARTIGNETTI COMPANIES', 'BACARDI USA INC            ',
#        'PERNOD RICARD USA          ', 'JIM BEAM BRANDS COMPANY    ',
#        'SAZERAC CO INC             ', 'PROXIMO SPIRITS INC.       ',
#        'ULTRA BEVERAGE COMPANY LLP ', 'MOET HENNESSY USA INC      ',
#        'E & J GALLO WINERY         ', 'STOLI GROUP,(USA) LLC      ',
#        'M S WALKER INC             ', 'SOUTHERN WINE & SPIRITS NE ',
#        'CAMPARI AMERICA            ', 'CONSTELLATION BRANDS INC   ',
#        'SAZERAC NORTH AMERICA INC. ', 'HEAVEN HILL DISTILLERIES   ',
#        'CASTLE BRANDS CORP.        ', 'MAJESTIC FINE WINES        ',
#        'SIDNEY FRANK IMPORTING CO  ', 'REMY COINTREAU USA INC     ',
#        'WILLIAM GRANT & SONS INC   ', 'MHW LTD                    ',
#        'DISARONNO INTERNATIONAL LLC', 'WINE GROUP INC             ',
#        'PERFECTA WINES             ', 'TREASURY WINE ESTATES      ',
# ...

# %% [markdown]
# ***There is irrelavant white spaces***

# %%
vendor_sales_summary['Volume'] = vendor_sales_summary['Volume'].astype('Float64')

# %%
vendor_sales_summary.fillna(0, inplace=True)

# %%
vendor_sales_summary["VendorName"] = vendor_sales_summary["VendorName"].str.strip()
vendor_sales_summary["VendorName"]
# Out:
# 0         DIAGEO NORTH AMERICA INC
# 1                BROWN-FORMAN CORP
# 2         DIAGEO NORTH AMERICA INC
# 3            MARTIGNETTI COMPANIES
# 4                  BACARDI USA INC
#                    ...
# 6489                WINE GROUP INC
# 6490    ULTRA BEVERAGE COMPANY LLP
# 6491                       MHW LTD
# 6492      DIAGEO NORTH AMERICA INC
# 6493          PROXIMO SPIRITS INC.
# Name: VendorName, Length: 6494, dtype: object

# %%
vendor_sales_summary.isnull().sum()
# Out:
# VendorNumber             0
# VendorName               0
# Brand                    0
# Purchaseprice            0
# Volume                   0
# ActualPrice              0
# TotalPurchaseQuantity    0
# TotalPurchaseDollars     0
# TotalSalesQuantity       0
# TotalSalesDollars        0
# TotalSalesPrice          0
# TotalExciseTax           0
# FreighhtCost             0
# dtype: int64

# %% [markdown]
# ***So here all inconsistency are removed and missing values are filled.***

# %% [markdown]
# ***Next, we make some columns that will be useful for further data analysis***

# %%
vendor_sales_summary["GrossProfit"] = vendor_sales_summary['TotalSalesDollars']-vendor_sales_summary['TotalPurchaseDollars']
vendor_sales_summary["GrossProfit"]
# Out:
# 0      -382956.54
# 1      -320797.49
# 2      -297618.96
# 3      -291208.63
# 4      -239167.27
#           ...
# 6489        -2.25
# 6490        14.64
# 6491       218.24
# 6492         2.54
# 6493         0.28
# Name: GrossProfit, Length: 6494, dtype: float64

# %%
vendor_sales_summary["ProfitMargin"] = (vendor_sales_summary['GrossProfit']/vendor_sales_summary['TotalPurchaseDollars'])*100
vendor_sales_summary["ProfitMargin"]
# Out:
# 0         -80.639961
# 1         -82.338027
# 2         -81.958618
# 3         -86.104696
# 4         -84.176917
#             ...
# 6489     -100.000000
# 6490      668.493151
# 6491    14171.428571
# 6492      178.873239
# 6493       39.436620
# Name: ProfitMargin, Length: 6494, dtype: float64

# %%
vendor_sales_summary['StockTurnover'] = vendor_sales_summary['TotalSalesQuantity']/vendor_sales_summary['TotalPurchaseQuantity']
vendor_sales_summary['StockTurnover']
# Out:
# 0         0.142361
# 1         0.128919
# 2         0.131111
# 3         0.107447
# 4         0.117206
#            ...
# 6489      0.000000
# 6490      5.666667
# 6491    111.000000
# 6492      2.000000
# 6493      1.000000
# Name: StockTurnover, Length: 6494, dtype: float64

# %%
vendor_sales_summary["SalestoPurchaseRatio"] = vendor_sales_summary['TotalSalesDollars']/vendor_sales_summary['TotalPurchaseDollars']
vendor_sales_summary["SalestoPurchaseRatio"]
# Out:
# 0         0.193600
# 1         0.176620
# 2         0.180414
# 3         0.138953
# 4         0.158231
#            ...
# 6489      0.000000
# 6490      7.684932
# 6491    142.714286
# 6492      2.788732
# 6493      1.394366
# Name: SalestoPurchaseRatio, Length: 6494, dtype: float64

# %%
vendor_sales_summary.columns
# Out:
# Index(['VendorNumber', 'VendorName', 'Brand', 'Purchaseprice', 'Volume',
#        'ActualPrice', 'TotalPurchaseQuantity', 'TotalPurchaseDollars',
#        'TotalSalesQuantity', 'TotalSalesDollars', 'TotalSalesPrice',
#        'TotalExciseTax', 'FreighhtCost', 'GrossProfit', 'ProfitMargin',
#        'StockTurnover', 'SalestoPurchaseRatio'],
#       dtype='object')

# %%
cursor = conn.cursor()

# %%
cursor.execute("""CREATE TABLE vendor_sale_summary(
    VendorNumber INT,
    VendorName VARCHAR(100),
    Brand INT,
    Description VARCHAR(100),
    Purchaseprice DECIMAL(10,2),
    Volume ,
    ActualPrice DECIMAL(10,2),
    TotalPurchaseQuantity INT,
    TotalPurchaseDollars DECIMAL(10,2),
    TotalSalesQuantity INT,
    TotalSalesDollars DECIMAL(15,2),
    TotalSalesPrice DECIMAL(15,2),
    TotalExciseTax DECIMAL(15,2),
    FreighhtCost DECIMAL(15,2),
    GrossProfit DECIMAL(15,2),
    ProfitMargin DECIMAL(15,2),
    StockTurnover DECIMAL(15,2),
    SalestoPurchaseRatio DECIMAL(15,2),
    PRIMARY KEY (VendorNumber, Brand)
);""")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /tmp/ipython-input-3038816098.py in <cell line: 0>()
# ----> 1 cursor.execute("""CREATE TABLE vendor_sale_summary(
#       2     VendorNumber INT,
#       3     VendorName VARCHAR(100),
#       4     Brand INT,
#       5     Description VARCHAR(100),
#
# OperationalError: table vendor_sale_summary already exists

# %%
pd.read_sql_query('select * from vendor_sale_summary',conn)
# Out:
#       VendorNumber                  VendorName  Brand  Purchaseprice  Volume  \
# 0             3960    DIAGEO NORTH AMERICA INC   4261          16.17  1750.0
# 1             1128           BROWN-FORMAN CORP   1233          26.27  1750.0
# 2             3960    DIAGEO NORTH AMERICA INC   3545          21.89  1750.0
# 3             4425       MARTIGNETTI COMPANIES   3405          23.19  1750.0
# 4              480             BACARDI USA INC   3858          17.77   750.0
# ...            ...                         ...    ...            ...     ...
# 6489          9815              WINE GROUP INC  22407           2.25   750.0
# 6490          9165  ULTRA BEVERAGE COMPANY LLP   9191           0.73    50.0
# 6491          6213                     MHW LTD   4703           0.77    50.0
# 6492          3960    DIAGEO NORTH AMERICA INC   8495           0.71    50.0
# 6493          7245        PROXIMO SPIRITS INC.   3065           0.71    50.0
#
# ...

# %%
vendor_sales_summary.to_sql('vendor_sale_summary', conn, if_exists='replace', index=False)
conn.commit()

# %%
pd.read_sql_query('select * from vendor_sale_summary',conn)
# Out:
#       VendorNumber                  VendorName  Brand  Purchaseprice  Volume  \
# 0             3960    DIAGEO NORTH AMERICA INC   4261          16.17  1750.0
# 1             1128           BROWN-FORMAN CORP   1233          26.27  1750.0
# 2             3960    DIAGEO NORTH AMERICA INC   3545          21.89  1750.0
# 3             4425       MARTIGNETTI COMPANIES   3405          23.19  1750.0
# 4              480             BACARDI USA INC   3858          17.77   750.0
# ...            ...                         ...    ...            ...     ...
# 6489          9815              WINE GROUP INC  22407           2.25   750.0
# 6490          9165  ULTRA BEVERAGE COMPANY LLP   9191           0.73    50.0
# 6491          6213                     MHW LTD   4703           0.77    50.0
# 6492          3960    DIAGEO NORTH AMERICA INC   8495           0.71    50.0
# 6493          7245        PROXIMO SPIRITS INC.   3065           0.71    50.0
#
# ...

# %%
pd.read_sql_query('select * from vendor_sale_summary',conn)
# Out:
#       VendorNumber                  VendorName  Brand  Purchaseprice  Volume  \
# 0             3960    DIAGEO NORTH AMERICA INC   4261          16.17  1750.0
# 1             1128           BROWN-FORMAN CORP   1233          26.27  1750.0
# 2             3960    DIAGEO NORTH AMERICA INC   3545          21.89  1750.0
# 3             4425       MARTIGNETTI COMPANIES   3405          23.19  1750.0
# 4              480             BACARDI USA INC   3858          17.77   750.0
# ...            ...                         ...    ...            ...     ...
# 6489          9815              WINE GROUP INC  22407           2.25   750.0
# 6490          9165  ULTRA BEVERAGE COMPANY LLP   9191           0.73    50.0
# 6491          6213                     MHW LTD   4703           0.77    50.0
# 6492          3960    DIAGEO NORTH AMERICA INC   8495           0.71    50.0
# 6493          7245        PROXIMO SPIRITS INC.   3065           0.71    50.0
#
# ...
